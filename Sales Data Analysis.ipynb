# %%
import pandas as pd

# %%
file_path = 'ECOMM DATA.xlsx'
sales_data = pd.read_excel(file_path)

# %%
sales_data.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
sales_data.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
sales_data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
sales_data_cleaned = sales_data.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 0 to 51287
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   City            9994 non-null   object
#  9   State           9994 non-null   object
#  10  Country         9994 non-null   object
#  11  Postal Code     9994 non-null   float64
#  12  Market          9994 non-null   object
#  13  Region          9994 non-null   object
#  14  Product ID      9994 non-null   object
#  15  Category        9994 non-null   object
#  16  Sub-Category    9994 non-null   object
# ...

# %%
sales_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 0 to 51287
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   City            9994 non-null   object
#  9   State           9994 non-null   object
#  10  Country         9994 non-null   object
#  11  Postal Code     9994 non-null   float64
#  12  Market          9994 non-null   object
#  13  Region          9994 non-null   object
#  14  Product ID      9994 non-null   object
#  15  Category        9994 non-null   object
#  16  Sub-Category    9994 non-null   object
# ...

# %%
sales_data_cleaned['Total Sales'] = sales_data_cleaned['Quantity'] * sales_data_cleaned['Profit']

# %%
sales_data_cleaned.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    32298  CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 8    40155  CA-2014-135909 2014-10-14 2014-10-21  Standard Class    JW-15220
# 9    40936  CA-2012-116638 2012-01-28 2012-01-31    Second Class    JH-15985
# 10   34577  CA-2011-102988 2011-04-05 2011-04-09    Second Class    GM-14695
# 16   36178  CA-2014-143567 2014-11-03 2014-11-06    Second Class    TB-21175
#
#     Customer Name    Segment           City           State  ...  \
# 0     Rick Hansen   Consumer  New York City        New York  ...
# 8       Jane Waco  Corporate     Sacramento      California  ...
# 9     Joseph Holt   Consumer        Concord  North Carolina  ...
# 10   Greg Maxwell  Corporate     Alexandria        Virginia  ...
# 16  Thomas Boland  Corporate      Henderson        Kentucky  ...
#
#            Category  Sub-Category  \
# 0        Technology   Accessories
# 8   Office Supplies       Binders
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
sales_trend = sales_data_cleaned.groupby('Order Date')['Total Sales'].sum()

# %%
sales_trend_rolling = sales_trend.rolling(window=7).mean()

# %%
plt.figure(figsize=(14, 8))
plt.plot(sales_trend.index, sales_trend.values, label='Daily Sales', color='blue', alpha=0.6)
plt.plot(sales_trend_rolling.index, sales_trend_rolling.values, label='7-Day Rolling Average', color='red', linewidth=2)
plt.axvline(pd.Timestamp('2023-11-24'), color='green', linestyle='--', linewidth=2, label='Black Friday')
plt.text(pd.Timestamp('2023-11-24'), max(sales_trend), 'Black Friday', color='green', fontsize=12, ha='right')
max_sales_date = sales_trend.idxmax()
max_sales_value = sales_trend.max()

plt.annotate(f'Highest Sales: ${max_sales_value:.2f}', xy=(max_sales_date, max_sales_value),
             xytext=(max_sales_date, max_sales_value + max_sales_value * 0.1),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=12, ha='center', color='black')

plt.title('Sales Trend Over Time', fontsize=18)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
best_selling_products = sales_data_cleaned.groupby('Product Name')['Total Sales'].sum().sort_values(ascending=False)
best_selling_products.head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          104159.7024
# Hewlett Packard LaserJet 3310 Copier                                            44087.2652
# GBC Ibimaster 500 Manual ProClick Binding System                                37592.4120
# Canon PC1060 Personal Laser Copier                                              26326.6239
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     22496.5230
# Ativa V4110MDD Micro-Cut Shredder                                               22294.6815
# 3D Systems Cube Printer, 2nd Generation, Magenta                                21969.8310
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       20124.8850
# Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room              19001.0800
# Fellowes PB300 Plastic Comb Binding Machine                                     17440.1505
# Name: Total Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
top_products = best_selling_products.head(10)

# %%
plt.figure(figsize=(10, 6))
bars = plt.barh(top_products.index, top_products.values, color='pink')

for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, 
             f'${bar.get_width():,.2f}', 
             va='center', ha='left', color='black', fontsize=10)

plt.title('Top 10 Best-Selling Products', fontsize=16, fontweight='bold')
plt.xlabel('Total Sales', fontsize=14)
plt.ylabel('Product', fontsize=14)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %%
avg_sales_per_transaction = sales_data_cleaned['Total Sales'].mean()
high_value_customers = sales_data_cleaned.groupby('Customer ID')['Total Sales'].sum().sort_values(ascending=False)
high_value_customers.head(10)
# Out:
# Customer ID
# AB-10105    65852.7459
# TC-20980    43892.2523
# RB-19360    28189.0323
# DR-12940    26452.7664
# SC-20095    26152.9003
# CM-12385    21465.4788
# TA-21385    21264.6011
# HL-15040    18406.3404
# BS-11365    18075.8188
# HM-14860    15843.2118
# Name: Total Sales, dtype: float64

# %%
sales_by_category = sales_data_cleaned.groupby('Category')['Total Sales'].sum()

# %%
plt.figure(figsize=(8, 8))
colors = plt.cm.Paired(range(len(sales_by_category)))  # Generate a color map for the pie chart
plt.pie(sales_by_category, labels=sales_by_category.index, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Total Sales by Category')
plt.show()
